# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
import numpy as np

# %%
# Read csv file into dataframe
df = pd.read_csv("../DataSets/HW1Q3.csv")

# %%
plt.plot(df["year of release"],df["Speed (mph)"])
plt.xlabel("Year of release")
plt.ylabel("Top speed (mph)")
plt.show()
